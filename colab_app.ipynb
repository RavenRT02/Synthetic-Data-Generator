# %% [markdown]
# ## For colab execution -- Run this file in google colab
# ## Set to load Llama3.1
# ## To use api keys, refer README.md

# %%
# Clone repo

# !git clone https://github.com/RavenRT02/Synthetic-Data-Generator.git

# %%
# Navigate to temp repo store and install requirements

# %cd Synthetic-Data-Generator
# !pip install -q -r requirements.txt

# %%
# Get userdata from colab and call login-huggingface function -- Required for Llama3.1

from google.colab import userdata
from llm.auth import login_huggingface
login_huggingface(userdata.get("HF_TOKEN"))

# %%
# run app - Launches gradio UI

from app import main
main()
